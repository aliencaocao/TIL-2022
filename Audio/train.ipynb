# %%
import os
import shutil
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.keras import models, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
import tensorflow_addons as tfa
from tensorflow.keras import backend as K

# %%
seed = 69
tf.random.set_seed(seed)
np.random.seed(seed)
sample_rate = 16000

data_dir = 'data/combined_normalized'
classes = np.array(os.listdir(data_dir))
num_classes = len(classes)

classes_index = {label: index for index, label in enumerate(classes)}
print('Classes:', classes_index)

filenames = tf.io.gfile.glob(data_dir + '/*/*')
labels = [classes_index[f.split(os.path.sep)[-2]] for f in filenames]
num_samples = len(filenames)
print('Number of total examples:', num_samples)

x_train, x_val, y_train, y_val = train_test_split(filenames, labels, test_size=0.2, random_state=seed, shuffle=True, stratify=labels)

print('Train:', len(x_train))
print(collections.Counter(y_train))
print('Val:', len(x_val))
print(collections.Counter(y_val))
# Out:
# Classes: {'angry': 0, 'fear': 1, 'happy': 2, 'neutral': 3, 'sad': 4}
# Number of total examples: 9531
# Train: 7624
# Counter({0: 1603, 2: 1559, 1: 1557, 4: 1552, 3: 1353})
# Val: 1907
# Counter({0: 401, 2: 390, 1: 389, 4: 388, 3: 339})

# %%
wav = tf.io.read_file(x_train[0])
wav, sr = tf.audio.decode_wav(wav, desired_channels=1)
wav = tf.squeeze(wav, axis=-1) * 32768.0
sr = tf.cast(sr, dtype=tf.int64)
wav = tfio.audio.resample(wav, rate_in=sr, rate_out=sample_rate)
spectrogram = tfio.audio.spectrogram(wav, nfft=512, window=512, stride=256)
mel_spectrogram = tfio.audio.melscale(spectrogram, rate=sample_rate, mels=128, fmin=80, fmax=7600)
mel_spectrogram = tfio.audio.freq_mask(mel_spectrogram, param=10)
mel_spectrogram = tfio.audio.time_mask(mel_spectrogram, param=10)
mel_spectrogram = tf.expand_dims(mel_spectrogram, axis=-1)
mel_spectrogram = tf.image.resize_with_pad(mel_spectrogram, target_height=224, target_width=224, method=tf.image.ResizeMethod.BILINEAR)
plt.figure()
plt.imshow(tf.math.log(mel_spectrogram).numpy())
print(mel_spectrogram.shape)
# Out:
# (376, 128, 1)

# %%
@tf.function(jit_compile=False)
def preprocess(filepath):
      wav = tf.io.read_file(filepath)
      wav, sr = tf.audio.decode_wav(wav, desired_channels=1)
      wav = tf.squeeze(wav, axis=-1)
      if no_norm: wav *= 32768.0
      sr = tf.cast(sr, dtype=tf.int64)
      wav = tfio.audio.resample(wav, rate_in=sr, rate_out=sample_rate)
      spectrogram = tfio.audio.spectrogram(wav, nfft=512, window=512, stride=256)
      mel_spectrogram = tfio.audio.melscale(spectrogram, rate=sample_rate, mels=128, fmin=80, fmax=7600)

      # Augmentations
      # mel_spectrogram = tfio.audio.freq_mask(mel_spectrogram, param=10)
      # mel_spectrogram = tfio.audio.time_mask(mel_spectrogram, param=10)

      # Resizing
      mel_spectrogram = tf.expand_dims(mel_spectrogram, axis=-1)
      mel_spectrogram = tf.image.resize_with_pad(mel_spectrogram, target_height=224, target_width=224, method=tf.image.ResizeMethod.BILINEAR)  # any sharper resizing method produce black gaps
      mel_spectrogram = tf.squeeze(tf.stack([mel_spectrogram, mel_spectrogram, mel_spectrogram], axis=-1))
      mel_spectrogram.set_shape([224, 224, 3])
      return mel_spectrogram, tf.one_hot(tf.argmax(tf.strings.split(filepath, os.path.sep)[-2] == classes), len(classes))


@tf.function(jit_compile=False)
def preprocess_val(filepath):
      wav = tf.io.read_file(filepath)
      wav, sr = tf.audio.decode_wav(wav, desired_channels=1)
      wav = tf.squeeze(wav, axis=-1)
      if no_norm: wav *= 32768.0
      sr = tf.cast(sr, dtype=tf.int64)
      wav = tfio.audio.resample(wav, rate_in=sr, rate_out=sample_rate)
      spectrogram = tfio.audio.spectrogram(wav, nfft=512, window=512, stride=256)
      mel_spectrogram = tfio.audio.melscale(spectrogram, rate=sample_rate, mels=128, fmin=80, fmax=7600)

      # Augmentations
      # mel_spectrogram = tfio.audio.freq_mask(mel_spectrogram, param=10)
      # mel_spectrogram = tfio.audio.time_mask(mel_spectrogram, param=10)

      # Resizing
      mel_spectrogram = tf.expand_dims(mel_spectrogram, axis=-1)
      mel_spectrogram = tf.image.resize_with_pad(mel_spectrogram, target_height=224, target_width=224, method=tf.image.ResizeMethod.BILINEAR)  # any sharper resizing method produce black gaps
      mel_spectrogram = tf.squeeze(tf.stack([mel_spectrogram, mel_spectrogram, mel_spectrogram], axis=-1))
      mel_spectrogram.set_shape([224, 224, 3])
      return mel_spectrogram, tf.one_hot(tf.argmax(tf.strings.split(filepath, os.path.sep)[-2] == classes), len(classes))


no_norm = True  # set to False if model expects between 0 and 1, else set to True and let the model do preprocessing
train_ds = tf.data.Dataset.from_tensor_slices(x_train).map(preprocess, num_parallel_calls=-1)
val_ds = tf.data.Dataset.from_tensor_slices(x_val).map(preprocess_val, num_parallel_calls=-1)

batch_size = 32
train_ds = train_ds.batch(batch_size).cache().prefetch(-1)
val_ds = val_ds.batch(batch_size).cache().prefetch(-1)
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample

# %%
# test data
c = 0
for i in x_train:
      try:
            wav = tf.io.read_file(os.path.abspath(i))
            wav, sr = tf.audio.decode_wav(wav, desired_channels=1)
      except Exception as e:
            c += 1
            shutil.move(i, os.path.abspath(os.path.join(data_dir, 'bad_files/', i.split(os.path.sep)[-1])))

for i in x_val:
      try:
            wav = tf.io.read_file(os.path.abspath(i))
            wav, sr = tf.audio.decode_wav(wav, desired_channels=1)
      except Exception as e:
            c += 1
            shutil.move(i, os.path.abspath(os.path.join(data_dir, 'bad_files/', i.split(os.path.sep)[-1])))

c
# Out:
# 0

# %%
# Training
# NO preprocessing needed! Already scaled
xInput = Input((224, 224, 3))
# x = tf.keras.applications.resnet_v2.preprocess_input(xInput)
# pretrained = tf.keras.applications.EfficientNetV2S(include_top=False, weights='imagenet', input_tensor=xInput)
# pretrained = tf.keras.applications.MobileNetV3Large(alpha=1.0, minimalistic=False, include_top=False, weights='imagenet', input_tensor=xInput, include_preprocessing=False)
# pretrained = tf.keras.applications.resnet_v2.ResNet50V2(include_top=False, weights='imagenet', input_tensor=x)
pretrained = tf.keras.applications.regnet.RegNetX016(include_top=False, weights='imagenet')
# for layer in pretrained.layers:  # switch all relu to swish
#     try:
#         if layer.activation == tf.keras.activations.relu:
#             layer.activation = tf.keras.activations.swish
#     except AttributeError:
#         pass
x = pretrained(xInput)
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='swish')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='swish')(x)
x = Dropout(0.3)(x)
xOutput = Dense(len(classes))(x)  # no activation as loss using logit=True
model = tf.keras.models.Model(xInput, xOutput)

# %%
epoch = 25
# opt_lr_schedule = tf.keras.optimizers.schedules.CosineDecay(1e-3, epoch * 239)
opt = tf.keras.optimizers.Adam(learning_rate=5e-4)
opt = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=5e-5)
opt = tfa.optimizers.Lookahead(opt)
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1)
metrics = ['accuracy', tfa.metrics.F1Score(num_classes=len(classes), average='macro', threshold=0.5)]
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_f1_score', min_delta=0, patience=6, verbose=1, mode='max', restore_best_weights=True),
    # tf.keras.callbacks.ModelCheckpoint('./best_model',monitor='val_accuracy',save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_f1_score', mode='max', factor=0.1, patience=3, verbose=1)
]
model.compile(optimizer=opt, loss=loss, metrics=metrics)
plot_model(model, show_shapes=True, show_dtype=True, show_layer_names=True, to_file='model.png') # SC1_ensemble.png
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  regnetx016 (Functional)     (None, None, None, 912)   8320640
#
#  flatten (Flatten)           (None, 44688)             0
#
#  dropout (Dropout)           (None, 44688)             0
#
#  dense (Dense)               (None, 128)               5720192
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 14,057,989
# Trainable params: 14,014,485
# Non-trainable params: 43,504
# _________________________________________________________________

# %%
history = model.fit(train_ds, epochs=epoch, validation_data=val_ds, callbacks=callbacks, use_multiprocessing=True, verbose=1)
# Out:
# Epoch 1/25
# 239/239 [==============================] - 58s 140ms/step - loss: 1.5752 - accuracy: 0.3484 - f1_score: 0.2986 - val_loss: 1.3368 - val_accuracy: 0.4143 - val_f1_score: 0.4023 - lr: 0.0010
# Epoch 2/25
# 239/239 [==============================] - 24s 102ms/step - loss: 1.3146 - accuracy: 0.4778 - f1_score: 0.4553 - val_loss: 1.2109 - val_accuracy: 0.5496 - val_f1_score: 0.5236 - lr: 0.0010
# Epoch 3/25
# 239/239 [==============================] - 26s 107ms/step - loss: 1.1482 - accuracy: 0.6036 - f1_score: 0.5666 - val_loss: 1.0826 - val_accuracy: 0.6261 - val_f1_score: 0.5809 - lr: 0.0010
# Epoch 4/25
# 239/239 [==============================] - 25s 103ms/step - loss: 1.0790 - accuracy: 0.6396 - f1_score: 0.6046 - val_loss: 1.1046 - val_accuracy: 0.6041 - val_f1_score: 0.6011 - lr: 0.0010
# Epoch 5/25
# 239/239 [==============================] - 25s 105ms/step - loss: 0.9879 - accuracy: 0.6957 - f1_score: 0.6495 - val_loss: 1.0200 - val_accuracy: 0.6759 - val_f1_score: 0.6511 - lr: 0.0010
# Epoch 6/25
# 239/239 [==============================] - 25s 103ms/step - loss: 0.8535 - accuracy: 0.7757 - f1_score: 0.7045 - val_loss: 1.0644 - val_accuracy: 0.6681 - val_f1_score: 0.6552 - lr: 0.0010
# Epoch 7/25
# 239/239 [==============================] - 27s 113ms/step - loss: 0.7545 - accuracy: 0.8303 - f1_score: 0.7534 - val_loss: 1.2924 - val_accuracy: 0.5826 - val_f1_score: 0.5687 - lr: 0.0010
# Epoch 8/25
# 239/239 [==============================] - 28s 119ms/step - loss: 0.6594 - accuracy: 0.8844 - f1_score: 0.7959 - val_loss: 1.0497 - val_accuracy: 0.6859 - val_f1_score: 0.6715 - lr: 0.0010
# Epoch 9/25
# 239/239 [==============================] - 30s 127ms/step - loss: 0.5827 - accuracy: 0.9239 - f1_score: 0.8370 - val_loss: 3.5044 - val_accuracy: 0.2706 - val_f1_score: 0.3173 - lr: 0.0010
# Epoch 10/25
# 239/239 [==============================] - 31s 131ms/step - loss: 0.6311 - accuracy: 0.8949 - f1_score: 0.8159 - val_loss: 1.1101 - val_accuracy: 0.6754 - val_f1_score: 0.6616 - lr: 0.0010
# Epoch 11/25
# 239/239 [==============================] - 27s 114ms/step - loss: 0.5181 - accuracy: 0.9562 - f1_score: 0.8864 - val_loss: 1.0885 - val_accuracy: 0.6864 - val_f1_score: 0.6826 - lr: 0.0010
# Epoch 12/25
# 239/239 [==============================] - 36s 153ms/step - loss: 0.4903 - accuracy: 0.9680 - f1_score: 0.9079 - val_loss: 1.0977 - val_accuracy: 0.6854 - val_f1_score: 0.6883 - lr: 0.0010
# Epoch 13/25
# 239/239 [==============================] - 34s 141ms/step - loss: 0.4790 - accuracy: 0.9735 - f1_score: 0.9191 - val_loss: 1.2452 - val_accuracy: 0.6487 - val_f1_score: 0.6498 - lr: 0.0010
# Epoch 14/25
# 239/239 [==============================] - 27s 113ms/step - loss: 0.4638 - accuracy: 0.9806 - f1_score: 0.9295 - val_loss: 1.1691 - val_accuracy: 0.6817 - val_f1_score: 0.6841 - lr: 0.0010
# Epoch 15/25
# 239/239 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.9845 - f1_score: 0.9411
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 239/239 [==============================] - 25s 106ms/step - loss: 0.4537 - accuracy: 0.9845 - f1_score: 0.9411 - val_loss: 1.1338 - val_accuracy: 0.6691 - val_f1_score: 0.6786 - lr: 0.0010
# Epoch 16/25
# 239/239 [==============================] - 25s 105ms/step - loss: 0.4364 - accuracy: 0.9923 - f1_score: 0.9550 - val_loss: 1.0320 - val_accuracy: 0.7200 - val_f1_score: 0.7085 - lr: 1.0000e-04
# Epoch 17/25
# 239/239 [==============================] - 30s 124ms/step - loss: 0.4181 - accuracy: 0.9990 - f1_score: 0.9752 - val_loss: 1.0299 - val_accuracy: 0.7163 - val_f1_score: 0.7110 - lr: 1.0000e-04
# Epoch 18/25
# 239/239 [==============================] - 25s 106ms/step - loss: 0.4138 - accuracy: 0.9996 - f1_score: 0.9831 - val_loss: 1.0271 - val_accuracy: 0.7216 - val_f1_score: 0.7126 - lr: 1.0000e-04
# Epoch 19/25
# 239/239 [==============================] - 25s 106ms/step - loss: 0.4125 - accuracy: 0.9995 - f1_score: 0.9875 - val_loss: 1.0259 - val_accuracy: 0.7247 - val_f1_score: 0.7126 - lr: 1.0000e-04
# Epoch 20/25
# 239/239 [==============================] - 24s 102ms/step - loss: 0.4104 - accuracy: 0.9999 - f1_score: 0.9882 - val_loss: 1.0219 - val_accuracy: 0.7216 - val_f1_score: 0.7142 - lr: 1.0000e-04
# Epoch 21/25
# 239/239 [==============================] - 25s 106ms/step - loss: 0.4094 - accuracy: 0.9999 - f1_score: 0.9915 - val_loss: 1.0189 - val_accuracy: 0.7231 - val_f1_score: 0.7138 - lr: 1.0000e-04
# Epoch 22/25
# 239/239 [==============================] - 25s 105ms/step - loss: 0.4081 - accuracy: 0.9997 - f1_score: 0.9938 - val_loss: 1.0194 - val_accuracy: 0.7263 - val_f1_score: 0.7130 - lr: 1.0000e-04
# Epoch 23/25
# 239/239 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.9999 - f1_score: 0.9927
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 239/239 [==============================] - 24s 101ms/step - loss: 0.4079 - accuracy: 0.9999 - f1_score: 0.9927 - val_loss: 1.0158 - val_accuracy: 0.7294 - val_f1_score: 0.7121 - lr: 1.0000e-04
# Epoch 24/25
# 239/239 [==============================] - 25s 105ms/step - loss: 0.4073 - accuracy: 0.9999 - f1_score: 0.9946 - val_loss: 1.0137 - val_accuracy: 0.7299 - val_f1_score: 0.7125 - lr: 1.0000e-05
# Epoch 25/25
# 142/239 [================>.............] - ETA: 9s - loss: 0.4067 - accuracy: 1.0000 - f1_score: 0.9953
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 history = model.fit(train_ds, epochs=epoch, validation_data=val_ds, callbacks=callbacks, use_multiprocessing=True, verbose=1)
#
# File C:\Program Files\Python39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python39\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File C:\Program Files\Python39\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('models/regnetx_19epoch_f1_7735_ranger')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 41). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/regnetx_19epoch_f1_7735_ranger\assets
# INFO:tensorflow:Assets written to: models/regnetx_19epoch_f1_7735_ranger\assets
